# %% [markdown]
# [<< 11. Builtin database in Python: SQLite](11_using_a_database.ipynb) | [Index](00_index.ipynb) | [13. Sending an email using Python >>](13_sending_an_email.ipynb)

# %% [markdown]
# # Using a REST API

# %%
from pprint import pprint

import requests

# %%
proxies = {
  "http": "http://proxy-dmz.intel.com:911",
  "https": "http://proxy-dmz.intel.com:912",
}

response = requests.get("https://randomuser.me/api/", proxies=proxies)

# %%
response.text

# %%
response.json()

# %%
response = requests.get("https://api.thecatapi.com/v1/breeds/abys", proxies=proxies)

pprint(response.json())

# %%
pprint(response.json()["name"])

# %% [markdown]
# ## Fetching data from HSDES

# %% [markdown]
# https://hsdes-api.intel.com/rest/doc/

# %% [markdown]
# https://wiki.ith.intel.com/display/HSDESWIKI/Python

# %%
# %pip install requests-kerberos

# %%
import requests
from requests_kerberos import HTTPKerberosAuth
import urllib3
 
 
headers = { 'Content-type': 'application/json' }
# Replace the ID here with some article ID
url = 'https://hsdes-api.intel.com/rest/article/2202652508'
response = requests.get(url, verify=False, auth=HTTPKerberosAuth(), headers = headers)
pprint(response.json())

# %% [markdown]
# [<< 11. Builtin database in Python: SQLite](11_using_a_database.ipynb) | [Index](00_index.ipynb) | [13. Sending an email using Python >>](13_sending_an_email.ipynb)
