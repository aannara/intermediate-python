# %% [markdown]
# # dis - Disassembler for Python bytecode

# %% [markdown]
# The `dis` module supports the analysis of CPython bytecode by disassembling it.
#
# It helps you understand the underlying instructions that the `Python interpreter` executes when running your code.
#
# The `dis` module is mainly used for debugging, optimization, and educational purposes.

# %%
import dis

# %%
def get_len(alist):
    return len(alist)

# %%
dis.dis(get_len)
# Out:
#   2           0 LOAD_GLOBAL              0 (len)
#               2 LOAD_FAST                0 (alist)
#               4 CALL_FUNCTION            1
#               6 RETURN_VALUE

# %%
bytecode = dis.Bytecode(get_len)
for instr in bytecode:
    print(instr)
# Out:
# Instruction(opname='LOAD_GLOBAL', opcode=116, arg=0, argval='len', argrepr='len', offset=0, starts_line=2, is_jump_target=False)
# Instruction(opname='LOAD_FAST', opcode=124, arg=0, argval='alist', argrepr='alist', offset=2, starts_line=None, is_jump_target=False)
# Instruction(opname='CALL_FUNCTION', opcode=131, arg=1, argval=1, argrepr='', offset=4, starts_line=None, is_jump_target=False)
# Instruction(opname='RETURN_VALUE', opcode=83, arg=None, argval=None, argrepr='', offset=6, starts_line=None, is_jump_target=False)

# %%
bytecode = dis.Bytecode(get_len)
for instr in bytecode:
    print(instr.opname)
# Out:
# LOAD_GLOBAL
# LOAD_FAST
# CALL_FUNCTION
# RETURN_VALUE

# %%
dis.show_code(get_len)
# Out:
# Name:              myfunc
# Filename:          C:\Users\aannara\AppData\Local\Temp\ipykernel_41916\1475142751.py
# Argument count:    1
# Positional-only arguments: 0
# Kw-only arguments: 0
# Number of locals:  1
# Stack size:        2
# Flags:             OPTIMIZED, NEWLOCALS, NOFREE
# Constants:
#    0: None
# Names:
#    0: len
# Variable names:
#    0: alist

# %%
def return_const():
    num = 2 + 3
    return num

# %%
dis.dis(return_const)
# Out:
#   2           0 LOAD_CONST               1 (5)
#               2 STORE_FAST               0 (num)
#
#   3           4 LOAD_FAST                0 (num)
#               6 RETURN_VALUE

# %%
bytecode = dis.Bytecode(return_const)
for instr in bytecode:
    print(instr)
# Out:
# Instruction(opname='LOAD_CONST', opcode=100, arg=1, argval=5, argrepr='5', offset=0, starts_line=2, is_jump_target=False)
# Instruction(opname='STORE_FAST', opcode=125, arg=0, argval='num', argrepr='num', offset=2, starts_line=None, is_jump_target=False)
# Instruction(opname='LOAD_FAST', opcode=124, arg=0, argval='num', argrepr='num', offset=4, starts_line=3, is_jump_target=False)
# Instruction(opname='RETURN_VALUE', opcode=83, arg=None, argval=None, argrepr='', offset=6, starts_line=None, is_jump_target=False)

# %%
bytecode = dis.Bytecode(return_const)
for instr in bytecode:
    print(instr.opname)
# Out:
# LOAD_CONST
# STORE_FAST
# LOAD_FAST
# RETURN_VALUE

# %%
dis.show_code(return_const)
# Out:
# Name:              return_const
# Filename:          C:\Users\aannara\AppData\Local\Temp\ipykernel_41916\9982043.py
# Argument count:    0
# Positional-only arguments: 0
# Kw-only arguments: 0
# Number of locals:  1
# Stack size:        1
# Flags:             OPTIMIZED, NEWLOCALS, NOFREE
# Constants:
#    0: None
#    1: 5
# Variable names:
#    0: num

# %%
def add_nums(a, b):
    return a + b

# %%
dis.dis(add_nums)
# Out:
#   2           0 LOAD_FAST                0 (a)
#               2 LOAD_FAST                1 (b)
#               4 BINARY_ADD
#               6 RETURN_VALUE

# %%
bytecode = dis.Bytecode(add_nums)
for instr in bytecode:
    print(instr)
# Out:
# Instruction(opname='LOAD_FAST', opcode=124, arg=0, argval='a', argrepr='a', offset=0, starts_line=2, is_jump_target=False)
# Instruction(opname='LOAD_FAST', opcode=124, arg=1, argval='b', argrepr='b', offset=2, starts_line=None, is_jump_target=False)
# Instruction(opname='BINARY_ADD', opcode=23, arg=None, argval=None, argrepr='', offset=4, starts_line=None, is_jump_target=False)
# Instruction(opname='RETURN_VALUE', opcode=83, arg=None, argval=None, argrepr='', offset=6, starts_line=None, is_jump_target=False)

# %%
bytecode = dis.Bytecode(add_nums)
for instr in bytecode:
    print(instr.opname)
# Out:
# LOAD_FAST
# LOAD_FAST
# BINARY_ADD
# RETURN_VALUE

# %%
dis.show_code(add_nums)
# Out:
# Name:              add_nums
# Filename:          C:\Users\aannara\AppData\Local\Temp\ipykernel_41916\1527640308.py
# Argument count:    2
# Positional-only arguments: 0
# Kw-only arguments: 0
# Number of locals:  2
# Stack size:        2
# Flags:             OPTIMIZED, NEWLOCALS, NOFREE
# Constants:
#    0: None
# Variable names:
#    0: a
#    1: b

# %%
def greater_number(a, b):
    if a > b:
        return a
    else:
        return b

# %%
dis.dis(greater_number)
# Out:
#   2           0 LOAD_FAST                0 (a)
#               2 LOAD_FAST                1 (b)
#               4 COMPARE_OP               4 (>)
#               6 POP_JUMP_IF_FALSE        6 (to 12)
#
#   3           8 LOAD_FAST                0 (a)
#              10 RETURN_VALUE
#
#   5     >>   12 LOAD_FAST                1 (b)
#              14 RETURN_VALUE

# %%
bytecode = dis.Bytecode(greater_number)
for instr in bytecode:
    print(instr)
# Out:
# Instruction(opname='LOAD_FAST', opcode=124, arg=0, argval='a', argrepr='a', offset=0, starts_line=2, is_jump_target=False)
# Instruction(opname='LOAD_FAST', opcode=124, arg=1, argval='b', argrepr='b', offset=2, starts_line=None, is_jump_target=False)
# Instruction(opname='COMPARE_OP', opcode=107, arg=4, argval='>', argrepr='>', offset=4, starts_line=None, is_jump_target=False)
# Instruction(opname='POP_JUMP_IF_FALSE', opcode=114, arg=6, argval=12, argrepr='to 12', offset=6, starts_line=None, is_jump_target=False)
# Instruction(opname='LOAD_FAST', opcode=124, arg=0, argval='a', argrepr='a', offset=8, starts_line=3, is_jump_target=False)
# Instruction(opname='RETURN_VALUE', opcode=83, arg=None, argval=None, argrepr='', offset=10, starts_line=None, is_jump_target=False)
# Instruction(opname='LOAD_FAST', opcode=124, arg=1, argval='b', argrepr='b', offset=12, starts_line=5, is_jump_target=True)
# Instruction(opname='RETURN_VALUE', opcode=83, arg=None, argval=None, argrepr='', offset=14, starts_line=None, is_jump_target=False)

# %%
bytecode = dis.Bytecode(greater_number)
for instr in bytecode:
    print(instr.opname)
# Out:
# LOAD_FAST
# LOAD_FAST
# COMPARE_OP
# POP_JUMP_IF_FALSE
# LOAD_FAST
# RETURN_VALUE
# LOAD_FAST
# RETURN_VALUE

# %%
dis.show_code(greater_number)
# Out:
# Name:              greater_number
# Filename:          C:\Users\aannara\AppData\Local\Temp\ipykernel_41916\3455522221.py
# Argument count:    2
# Positional-only arguments: 0
# Kw-only arguments: 0
# Number of locals:  2
# Stack size:        2
# Flags:             OPTIMIZED, NEWLOCALS, NOFREE
# Constants:
#    0: None
# Variable names:
#    0: a
#    1: b

# %%
def sum_range(n):
    total = 0
    for i in range(n):
        total += i
    return total

# %%
dis.dis(sum_range)
# Out:
#   2           0 LOAD_CONST               1 (0)
#               2 STORE_FAST               1 (total)
#
#   3           4 LOAD_GLOBAL              0 (range)
#               6 LOAD_FAST                0 (n)
#               8 CALL_FUNCTION            1
#              10 GET_ITER
#         >>   12 FOR_ITER                 6 (to 26)
#              14 STORE_FAST               2 (i)
#
#   4          16 LOAD_FAST                1 (total)
#              18 LOAD_FAST                2 (i)
#              20 INPLACE_ADD
#              22 STORE_FAST               1 (total)
#              24 JUMP_ABSOLUTE            6 (to 12)
#
#   5     >>   26 LOAD_FAST                1 (total)
#              28 RETURN_VALUE

# %%
bytecode = dis.Bytecode(sum_range)
for instr in bytecode:
    print(instr)
# Out:
# Instruction(opname='LOAD_CONST', opcode=100, arg=1, argval=0, argrepr='0', offset=0, starts_line=2, is_jump_target=False)
# Instruction(opname='STORE_FAST', opcode=125, arg=1, argval='total', argrepr='total', offset=2, starts_line=None, is_jump_target=False)
# Instruction(opname='LOAD_GLOBAL', opcode=116, arg=0, argval='range', argrepr='range', offset=4, starts_line=3, is_jump_target=False)
# Instruction(opname='LOAD_FAST', opcode=124, arg=0, argval='n', argrepr='n', offset=6, starts_line=None, is_jump_target=False)
# Instruction(opname='CALL_FUNCTION', opcode=131, arg=1, argval=1, argrepr='', offset=8, starts_line=None, is_jump_target=False)
# Instruction(opname='GET_ITER', opcode=68, arg=None, argval=None, argrepr='', offset=10, starts_line=None, is_jump_target=False)
# Instruction(opname='FOR_ITER', opcode=93, arg=6, argval=26, argrepr='to 26', offset=12, starts_line=None, is_jump_target=True)
# Instruction(opname='STORE_FAST', opcode=125, arg=2, argval='i', argrepr='i', offset=14, starts_line=None, is_jump_target=False)
# Instruction(opname='LOAD_FAST', opcode=124, arg=1, argval='total', argrepr='total', offset=16, starts_line=4, is_jump_target=False)
# Instruction(opname='LOAD_FAST', opcode=124, arg=2, argval='i', argrepr='i', offset=18, starts_line=None, is_jump_target=False)
# Instruction(opname='INPLACE_ADD', opcode=55, arg=None, argval=None, argrepr='', offset=20, starts_line=None, is_jump_target=False)
# Instruction(opname='STORE_FAST', opcode=125, arg=1, argval='total', argrepr='total', offset=22, starts_line=None, is_jump_target=False)
# Instruction(opname='JUMP_ABSOLUTE', opcode=113, arg=6, argval=12, argrepr='to 12', offset=24, starts_line=None, is_jump_target=False)
# Instruction(opname='LOAD_FAST', opcode=124, arg=1, argval='total', argrepr='total', offset=26, starts_line=5, is_jump_target=True)
# Instruction(opname='RETURN_VALUE', opcode=83, arg=None, argval=None, argrepr='', offset=28, starts_line=None, is_jump_target=False)

# %%
bytecode = dis.Bytecode(sum_range)
for instr in bytecode:
    print(instr.opname)
# Out:
# LOAD_CONST
# STORE_FAST
# LOAD_GLOBAL
# LOAD_FAST
# CALL_FUNCTION
# GET_ITER
# FOR_ITER
# STORE_FAST
# LOAD_FAST
# LOAD_FAST
# INPLACE_ADD
# STORE_FAST
# JUMP_ABSOLUTE
# LOAD_FAST
# RETURN_VALUE

# %%
dis.show_code(sum_range)
# Out:
# Name:              sum_range
# Filename:          C:\Users\aannara\AppData\Local\Temp\ipykernel_41916\3819880780.py
# Argument count:    1
# Positional-only arguments: 0
# Kw-only arguments: 0
# Number of locals:  3
# Stack size:        3
# Flags:             OPTIMIZED, NEWLOCALS, NOFREE
# Constants:
#    0: None
#    1: 0
# Names:
#    0: range
# Variable names:
#    0: n
#    1: total
#    2: i
